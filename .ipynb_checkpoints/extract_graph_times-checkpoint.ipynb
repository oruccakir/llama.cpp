# %%
res = {}
rnode = {}
llist = {}
with open("./../llama_graph_times.txt", "r") as f:
    for l in f:
        if "Compute forward" in l:
            nm = l[l.find("[")+1:l.find("]")]
            tm = int(l[l.find("(")+1:l.find(")")])
            nd = int(l.split(",")[0].split(" ")[-1])
            if nd in rnode:
                rnode[nd] += tm
            else:
                rnode[nd] = tm
            if not nm in res:
                print(nm, tm)
                res[nm] = tm
                llist[nm] = {nd}
            else:
                res[nm] += tm
                llist[nm].add(nd)
# Out:
# GGML_OP_RMS_NORM 2672
# GGML_OP_MUL 586
# GGML_OP_MUL_MAT 90192
# GGML_OP_RESHAPE 1
# GGML_OP_ROPE 1936
# GGML_OP_VIEW 2
# GGML_OP_CPY 1578
# GGML_OP_TRANSPOSE 2
# GGML_OP_PERMUTE 0
# GGML_OP_SOFT_MAX 8031
# GGML_OP_CONT 1028
# GGML_OP_ADD 1059
# GGML_OP_UNARY 2503
# GGML_OP_GET_ROWS 1

# %%
for k in res.keys():
    res[k] /= 1000000
for k in rnode.keys():
    rnode[k] /= 1000000

# %%
print(res)
# Out:
# {'GGML_OP_RMS_NORM': 0.369323, 'GGML_OP_MUL': 0.600533, 'GGML_OP_MUL_MAT': 144.456491, 'GGML_OP_RESHAPE': 0.002539, 'GGML_OP_ROPE': 0.330115, 'GGML_OP_VIEW': 0.002245, 'GGML_OP_CPY': 0.761838, 'GGML_OP_TRANSPOSE': 0.000416, 'GGML_OP_PERMUTE': 0.00138, 'GGML_OP_SOFT_MAX': 1.066445, 'GGML_OP_CONT': 0.152009, 'GGML_OP_ADD': 0.268793, 'GGML_OP_UNARY': 0.311674, 'GGML_OP_GET_ROWS': 0.000244}

# %%
print("Matrix multiplications layer count:",len(llist["GGML_OP_MUL_MAT"]))
print("Layers:",llist["GGML_OP_MUL_MAT"])
# Out:
# Matrix multiplications layer count: 542
# ...

# %%
vpr = []
for k in rnode:
    vpr.append((rnode[k], k))
vpr.sort()
vpr = vpr[::-1]
print(vpr)
# Out:
# [(1.407513, 766), (1.345242, 94), (1.336127, 574), (1.327959, 30), (1.322115, 286), (1.321694, 862), (1.318697, 190), (1.282736, 670), (1.280316, 478), (1.279509, 62), (1.276739, 926), (1.272816, 894), (1.263771, 382), (1.175582, 316), (1.158291, 826), (1.128991, 346), (1.11141, 314), (1.093064, 734), (1.05051, 798), (1.037904, 250), (1.02705, 126), (0.991163, 318), (0.988861, 794), (0.985945, 154), (0.979521, 730), (0.97663, 762), (0.97426, 732), (0.953326, 58), (0.952137, 764), (0.939414, 252), (0.932735, 796), (0.920603, 188), (0.915849, 858), (0.914687, 476), (0.913875, 538), (0.912824, 282), (0.912424, 828), (0.90835, 860), (0.90786, 284), (0.90611, 540), (0.905699, 700), (0.905156, 90), (0.901848, 218), (0.899842, 186), (0.898081, 830), (0.897882, 28), (0.897611, 380), (0.896235, 508), (0.895093, 890), (0.895077, 348), (0.894831, 922), (0.892768, 156), (0.891216, 92), (0.890367, 158), (0.889947, 26), (0.889793, 378), (0.888681, 254), (0.885723, 572), (0.880752, 122), (0.88072, 
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
idx = np.array([x for x in range(len(vpr))])
Y = np.array([x[0] for x in vpr])
plt.plot(idx, Y)

# %%
idx = np.array([x[1] for x in vpr])
Y = np.array([x[0] for x in vpr])
plt.scatter(idx, Y)
